# %% [markdown]
# <a href="https://colab.research.google.com/github/Jasonmiller513/Dissertation/blob/main/STEP_3_ENCODING_CATEGORICAL_VARIABLES.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **STEP 3: ENCODING CATEGORICAL VARIABLES**

# %%
df = pd.read_csv('dataco_rl_feature_engineered.csv', encoding='latin1')


print("Dataset Loaded")
print(df.shape)

# %%
import pandas as pd

df = pd.read_csv('dataco_rl_feature_engineered.csv', encoding='latin1')

one_hot_cols = [
    'Shipping Mode',
    'Market',
    'Order Region'
]

# Filter for columns that actually exist in the DataFrame
existing_one_hot_cols = [col for col in one_hot_cols if col in df.columns]

if existing_one_hot_cols:
    df = pd.get_dummies(
        df,
        columns=existing_one_hot_cols,
        drop_first=False
    )
else:
    print("Warning: None of the specified columns for one-hot encoding were found. Skipping one-hot encoding.")

df.to_csv(
    "dataco_rl_onehot.csv",
    index=False
)

print(df.shape)
